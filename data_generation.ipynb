# %%
from PIL import Image, ImageDraw
import json
import os

def create_image_layout(image_paths, output_path):
    # Calculate the layout dimensions based on the number of images
    num_images = len(image_paths)
    layout_width = 500  # You can adjust these dimensions based on your needs
    layout_height = 500
    image_size = 100     # Size of each image in the layout

    # Create a new blank image
    layout_image = Image.new('RGB', (layout_width, layout_height), 'white')
    draw = ImageDraw.Draw(layout_image)

    # Paste each image onto the layout
    for i, image_path in enumerate(image_paths):
        # Open the image using Pillow
        img = Image.open(image_path)
        img = img.resize((image_size, image_size), Image.LANCZOS)  # Resize image if needed

        # Calculate the position to paste the image
        row = i // (layout_width // image_size)
        col = i % (layout_width // image_size)
        x = col * image_size
        y = row * image_size

        # Paste the image onto the layout
        layout_image.paste(img, (x, y))

        # Draw a border around the image
        draw.rectangle([x, y, x + image_size, y + image_size], outline='black')

    # Save the layout image
    layout_image.save(output_path)

# Load the JSON file with image filenames and their groups of labels
with open('/Users/tejdavuluri/MSDS/isazi/baby_nutrition_updated_dataset/brandi_app_product_crops_candidates.json', 'r') as f:
    image_grouping_labels = json.load(f)

# Load the JSON file with image filenames and labels
with open('/Users/tejdavuluri/MSDS/isazi/baby_nutrition_updated_dataset/brandi_app_product_crops_lbls.json', 'r') as f:
    image_labels = json.load(f)

# Specify the directory where your images are stored
image_directory = '/Users/tejdavuluri/MSDS/isazi/baby_nutrition_updated_dataset/images'



# Create layouts for each group of images
for group_name, sub_image_labels in image_grouping_labels.items():
    layout_group_images=[]
    for key,val in image_labels.items():
        if val in sub_image_labels:
            layout_group_images.append(key)

    # Construct the full paths to the images
    image_paths = [os.path.join(image_directory, filename) for filename in layout_group_images]

    # Create an output path for the layout image
    output_path = f'/Users/tejdavuluri/MSDS/isazi/baby_nutrition_updated_dataset/layouts/{group_name}_layout.png'

    # Generate and save the layout image
    create_image_layout(image_paths, output_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 62
#      59 output_path = f'/Users/tejdavuluri/MSDS/isazi/baby_nutrition_updated_dataset/layouts/{group_name}_layout.png'
#      61 # Generate and save the layout image
# ---> 62 create_image_layout(image_paths, output_path)
#
# Cell In[3], line 20, in create_image_layout(image_paths, output_path)
#      17 for i, image_path in enumerate(image_paths):
#      18     # Open the image using Pillow
#      19     img = Image.open(image_path)
# ---> 20     img = img.resize((image_size, image_size), Image.LANCZOS)  # Resize image if needed
#      22     # Calculate the position to paste the image
#      23     row = i // (layout_width // image_size)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/PIL/Image.py:2174, in Image.resize(self, size, resample, box, reducing_gap)
#    2166             self = Image.reduce(self, factor, box=reduce_box)
#    2167         box = (
#    2168             (box[0] - reduce_box[0]) / factor_x,
#    2169             (box[1] - reduce_box[1]) / factor_y,
#    2170             (box[2] - reduce_box[0]) / factor_x,
#    2171             (box[3] - reduce_box[1]) / factor_y,
#    2172         )
# -> 2174 return self._new(self.im.resize(size, resample, box))
#
# KeyboardInterrupt:

# %%
import json
import os
with open('/Users/tejdavuluri/MSDS/isazi/baby_nutrition_updated_dataset/brandi_app_product_crops_candidates.json', 'r') as f:
    image_grouping_labels = json.load(f)

# %%
len(image_grouping_labels.items())
# Out:
# 35323

# %%
with open('/Users/tejdavuluri/MSDS/isazi/baby_nutrition_updated_dataset/brandi_app_product_crops_lbls.json', 'r') as f:
    image_labels = json.load(f)

# %%
image_labels.values()
# Out:
# dict_values(['6009516204388', '6009188002022', '6005118001295', '6001068639304', '6001068625505', '6009516203077', '6001156921304', '6001059949757', '6001068625703', '6009516203060', '6001068625406', '6009691190766', '6001068629008', '6009516204449', '6009516204401', '6009516203589', '6001068625307', '6009188002268', '6001068690909', '6001068661404', '6009188003593', '6009516204265', '6009516203060', '6009188002268', '6001068635405', '60050342', '6009516203046', '6009516200250', '6009516204449', '6001107396861', '6009188002268', '6009516203008', '6001059949801', '6001068625307', '6001059949337', '6009516202391', '6001068635405', '6001059949337', '6009691192999', '6001068625208', '6001068635405', '6001068625703', '6009651541607', '6001156921502', '6001059946657', '6001059949580', '6009516203039', '6009516202414', '6001068635405', '6001068629107', '6001068625802', '6001068661404', '6009516202391', '6001068635405', '6001068625208', '6009188001438', '6001068639205', '6009188002251', '6009516202414', '6001068639304', '6009516203039', '6001068631407', '6009651541546', '6009516202414', '6001059949320', '6009516203459', '6001059946657', '6001068625406', '6009188002268', '6009516200250', '6009516202414', '6009651541973', '6009516203053', '6001107000089', '6009188003593', '6001068625208', '6001068625802', '8710428994745', '6001059949757', '6001156921502', '6001068639304', '6006822002301', '6009516203923', '6009188003593', '6001107394287', '6001068697502', '6009516204265', '6009516202612', '6001059949764', '6001059949337', '6009516204432', '6001059949368', '6001059949757', '6001059947005', '6001068629107', '6009516200250', '6009879858228', '6001068697502', '6001068625703', '6001059949313', '6009651541980', '6009516203459', '6001068639304', '6001059949580', '6001068625208', '6001049058094', '6009516204258', '6009188002268', '6009651541997', '6009516202636', '6001059949368', '6001107158759', '6005044007477', '6001068629107', '6009516204449', '6001059949580', '6001049058117', '6001068635405', '6001068661404', '6009516203589', '6009516203602', '6009188003593', '6009516204388', '6009516203077', '6001068639304', '6009516204401', '6001068625406', '6001059946930', '6001068661404', '6009516203060', '6009879858181', '6009516203046', '6009516203084', '6001107394287', '6009802364260', '3518070023234', '6001107214813', '6001068626007', '8710428994745', '6009188002251', '6009516204449', '6009188002015', '6009516203015', '6009516202414', '6009188003593', '3518071533237', '6009516203596', '6001068661404', '6001049058117', '6009188001445', '6009516200250', '6009188003593', '6001068576500', '6009188003593', '6009516203039', '6005044007446', '6001068625802', '6009516203022', '6009516204272', '5391523056892', '6001068635405', '6009516202414', '6001068629008', '6009516203053', '6001156921502', '6009879858167', '6009516203336', '6009516204401', '6001068625505', '6001059949313', '6009516202414', '5391523056892', '6009651541881', '6009516204432', '6001068629008', '6009516204265', '6005044007453', '6005044007460', '6001059949368', '6009516202582', '6009516203008', '6001068625505', '6009516203053', '6001059949320', '6009651541898', '6009516203336', '6001068625406', '6001059949580', '6001068625406', '6001107000089', '6001068625505', '6009516203060', '6001059949313', '6009188002268', '6009516203473', '6001068582402', '6009188002268', '6009516203596', '6009516202636', '6009516203046', '6009516203589', '8427030005041', '6001068690909', '6009516204432', '6009516203084', '6009516202391', '6009516203077', '6001068625505', '6009516203459', '6009516203084', '6001059949580', '6009516204449', '6001068625703', '6005044007446', '6001059953808', '6009516204449', '6009516202414', '6001059949344', '6009516203626', '6001068635405', '6009516201530', '6001068629008', '6001068625208', '6009188003593', '6009516203701', '6001059949313', '6001068687909', '6001059949337', '6009651541973', '8002720003523', '6001059953808', '6009516201530', '6001059949580', '6009516202599', '6001059949764 ...
